# %%
"""
'FourSquare Method':

box 1: Income
-Rental
-Laundry
-Storage
-Miscellaneous
Total Monthly Income

box 2: Expenses
-Tax
-Insurance
-Utilities: (0 if tenant pays)
    -Electric
    -Water
    -Sewer
    -Garbage
    -Gas
-HOA Fees
-Lawn/Snow
-Vacancy (~5% of Rental Income)
-Repairs ($50-100 per unit)
-CapEx (~$100)
-Property Management (~10% of Rental Income unless self-managed)
-Mortgage (~5% of (Property Cost - Down Payment))
Total Monthly Expenses

box 3: Cash Flow
Income - Expenses
Total Monthly Cash Flow

box 4: Cash on Cash ROI
-Down Payment
-Closing Costs: ~15% of Property Cost unless otherwise specified
-Rehab Budget: ~35% of Property Cost unless otherwise specified
-Miscellaneous Other
Total Investment
Annual Cash Flow/Total Investment (as percentage)

Equity??
"""

# %%
class Property:
    def __init__(self,name):
        self.name = name
        self.cost = 0
        self.downpayment = 0
        self.units = []
        self.other_income = 0
        self.expenses = 0
        self.totali = 0

# %%
class BrandonInterface:
    def serve_Brandon(self):
        property_name = input('Greetings, Brandon, I exist solely in order to make your pockets even bigger than they already are. What is the name of the property whose ROI you wish me to analyze? ')
        property = Property(property_name.title())
        try:
            property.cost = float(input(f'What is the total cost of {property.name}? '))
        except:
            try:
                property.cost = float(input(f'Sorry, Brandon, I did not understand. Please enter a valid number for the cost of {property.name}. '))
            except:
                print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
        try:
            property.downpayment = float(input(f'And what is your down payment on {property.name}? '))
        except:
            try:
                property.downpayment = float(input(f'Sorry, Brandon, I did not understand. Please enter a valid number for your down payment on {property.name}. '))
            except:
                print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
        try:
            num_units = int(input(f"\nOk, Brandon, let's use your famous Four Square method and start by calculating your monthly income from {property.name}. How many rental units are in {property.name}? "))
        except:
            try:
                num_units = int(input(f"Sorry, Brandon, I did not understand. Please enter a valid number of rental units in {property.name}. "))
            except:
                print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
        while num_units < 1:
            try:
                num_units = int(input(f"Please enter a positive number of units in {property.name}, Brandon."))
            except:
                try:
                    num_units = int(input(f"Sorry, Brandon, I did not understand. Please enter a valid positive number of units in {property.name}, Brandon."))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                    break
        if num_units > 1:
            same_pricing = input(f'Is the rent for each unit in {property.name} the same? ')
            if same_pricing.lower() not in {'yes','no'}:
                same_pricing = input('I did not understand you, Brandon. Please answer yes or no. ')
                while same_pricing.lower() not in {'yes','no'}:
                    same_pricing = input(f'We could go on like this all day, Brandon. Please answer yes or no. ')
            if same_pricing.lower() == 'yes':
                try:
                    unit_price = float(input(f'Ok, Brandon, please enter the rent per unit in {property.name}: '))
                except:
                    try:
                        unit_price = float(input(f'Sorry, Brandon, I did not understand. Please enter a valid number for the rent per unit in {property.name}: '))
                    except:
                        print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                for _ in range(num_units):
                    property.units.append(unit_price)
            else:
                some_same = input(f'Ok, Brandon, no problem. Do any of the units in {property.name} have the same rent? ')
                if some_same.lower() not in {'yes','no'}:
                    some_same = input('I did not understand you, Brandon. Please answer yes or no. ')
                    while some_same.lower() not in {'yes','no'}:
                        some_same = input('We could go on like this all day, Brandon. Please answer yes or no. ')
                if some_same.lower() == 'yes':
                    try:
                        same_groups = int(input(f'Ok, Brandon, no problem. How many groups of units in {property.name} have the same rent? '))
                    except:
                        try:
                            same_groups = int(input(f'Sorry, Brandon, I did not understand. Please enter a valid number of groups of units in {property.name} that have the same rent: '))
                        except:
                            print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                    while same_groups > num_units or same_groups < 0:
                        try:
                            same_groups = int(input(f'That does not compute. How many groups of units in {property.name} have the same rent? '))
                        except:
                            try:
                                same_groups = int(input(f'Sorry, Brandon, I did not understand. Please enter a valid number of groups {i+1}: '))
                            except:
                                print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                                break
                    for i in range(same_groups):
                        try:
                            units_in_group = int(input(f'Ok, Brandon, how many units are in group {i+1}? '))
                        except:
                            try:
                                units_in_group = int(input(f'Sorry, Brandon, I did not understand. Please enter a valid number of units are in group {i+1}: '))
                            except:
                                print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                                break
                        while units_in_group + len(property.units) > num_units or units_in_group < 0:  
                            try:
                                units_in_group = int(input(f'That does not compute. How many units are in group {i+1}? '))
                            except:
                                try:
                                    units_in_group = int(input(f'Sorry, Brandon, I did not understand. Please enter a valid number of units in group {i+1}: '))
                                except:
                                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                                    break 
                        try:
                            unit_price = float(input(f'And what is the rent for each unit in group {i+1}? '))
                        except:
                            try:
                                unit_price = float(input(f'Sorry, Brandon, I did not understand. Please enter a valid number for the rent for each unit in group {i+1}: '))
                            except:
                                print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                                break
                        for j in range(units_in_group):
                            property.units.append(unit_price)
                    print(f'Ok, Brandon, that means {len(property.units)} out of {num_units} units belong to groups with the same rent. That leaves {num_units - len(property.units)} with different rent.\n')
                    while num_units > len(property.units):
                        try:
                            unit_price = float(input(f'Enter the rent for unit number {len(property.units)+1}: '))
                        except:
                            try:
                                unit_price = float(input(f'Sorry, Brandon, I did not understand. Please enter a valid number for the rent for unit number {len(property.units)+1}: '))
                            except:
                                print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                                break
                        property.units.append(unit_price)
                else:
                    while len(property.units) < num_units:
                        try:
                            unit_price = float(input(f'Ok, Brandon, enter the rent for unit number {len(property.units)+1}: '))
                        except:
                            try:
                                unit_price = float(input(f'Sorry, Brandon, I did not understand. Please enter a valid number for the rent for unit number {len(property.units)+1}: '))
                            except:
                                print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                                break
                        property.units.append(unit_price)
        elif num_units == 1:
            try:
                unit_price = float(input(f'Ok, Brandon, what is the rent for the unit at {property.name}? '))
            except:
                try:
                    unit_price = float(input(f'Sorry, Brandon, I did not understand. Please enter a valid number for the rent for the unit at {property.name}: '))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
        print(f"\nOk, Brandon, that brings your monthly rental income from {property.name} to the princely sum of ${sum(property.units):,.2f}. Let's see how much bigger that will make your pockets. Now I will ask you about other income streams from {property.name}.")
        laundry = input(f"\nDo you get income from a laundry machine or washerperson at {property.name}? ")
        if laundry.lower() not in {'yes','no'}:
            laundry = input('I did not understand you, Brandon. Please answer yes or no. ')
        while laundry.lower() not in {'yes','no'}:
            laundry = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if laundry.lower() == 'yes':
            try:
                laundry_income = float(input(f"That is very shrewd of you, Brandon. How much income does the laundry machine or washerperson at {property.name} net you each month? "))
            except:
                try:
                    laundry_income = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for your income from laundry at {property.name} each month: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.other_income += laundry_income
        storage = input(f"Do you get income from a storage facility at {property.name}? ")
        if storage.lower() not in {'yes','no'}:
            storage = input('I did not understand you, Brandon. Please answer yes or no. ')
        while storage.lower() not in {'yes','no'}:
            storage = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if storage.lower() == 'yes':
            try:
                storage_income = float(input(f"You display remarkable business acumen, Brandon. How much income does the storage facility at {property.name} net you each month? "))
            except:
                try:
                    storage_income = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for your income from storage at {property.name} each month: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.other_income += storage_income
        miscellaneous = input(f"Do you get income from any other miscellaneous sources at {property.name}, such as a vending machine or massage parlor? ")
        if miscellaneous.lower() not in {'yes','no'}:
            miscellaneous = input('I did not understand you, Brandon. Please answer yes or no. ')
        while miscellaneous.lower() not in {'yes','no'}:
            miscellaneous = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if miscellaneous.lower() == 'yes':
            try:
                miscellaneous_income = float(input(f"That is characteristically astute, Brandon. I won't pry into your private business, but how much income do these miscellaneous sources at {property.name} net you each month? "))
            except:
                try:
                    miscellaneous_income = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for your income from miscellaneous sources at {property.name} each month: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.other_income += miscellaneous_income
        print(f"\nOk, Brandon, so your total monthly income from {property.name} is ${sum(property.units) + property.other_income:,.2f}. I can feel your pockets getting bigger already. Now it is time to move onto box 2 of your celebrated Four Square method. Sadly, we must calculate your monthly expenses at {property.name}.")
        exacttax = input(f'\nWorst things first. Do you know the exact monthly property tax you must pay on {property.name}? (If not, we shall estimate it from an approximate percentage.) ')
        if exacttax.lower() not in {'yes','no'}:
            exacttax = input('I did not understand you, Brandon. Please answer yes or no. ')
        while exacttax.lower() not in {'yes','no'}:
            exacttax = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if exacttax.lower() == 'yes':
            try:
                tax = float(input(f"Very good, Brandon. I expected no less of you. Please enter the exact monthly property tax you must pay on {property.name}: "))
            except:
                try:
                    tax = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the exact monthly property tax on {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += tax
        else:
            try:
                tax = float(input(f"What is the approximate monthly property tax you must pay on {property.name}, as a percentage value between zero and one hundred? "))    
            except:
                try:
                    tax = float(input(f"Sorry, Brandon, I did not understand. Please enter the approximate monthly property tax on {property.name}, as a percentage value between zero and one hundred: "))    
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            while tax > 100 or tax < 0:
                try:
                    tax = float(input(f"Please enter a valid percentage value between zero and one hundred for the monthly property tax you must pay on {property.name}: "))    
                except:
                    try:
                        tax = float(input(f"Sorry, Brandon, I did not understand. Please enter the monthly property tax on {property.name}, as a percentage value between zero and one hundred: "))    
                    except:
                        print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += (tax/100)*property.cost
        exactinsurance = input(f'Do you know the exact monthly insurance you must pay on {property.name}? (If not, we shall estimate it from an approximate percentage.) ')
        if exactinsurance.lower() not in {'yes','no'}:
            exactinsurance = input('I did not understand you, Brandon. Please answer yes or no. ')
        while exactinsurance.lower() not in {'yes','no'}:
            exactinsurance = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if exactinsurance.lower() == 'yes':
            try:
                insurance = float(input(f"Excellent, Brandon. You never disappoint me. Please enter the exact monthly insurance you must pay on {property.name}: "))
            except:
                try:
                    insurance = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the exact monthly insurance on {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += insurance
        else:
            try:
                insurance = float(input(f"What is the approximate monthly insurance you must pay on {property.name}, as a percentage value between zero and one hundred? "))    
            except:
                try:
                    insurance = float(input(f"Sorry, Brandon, I did not understand. Please enter the approximate monthly insurance on {property.name}, as a percentage value between zero and one hundred: "))    
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            while insurance > 100 or insurance < 0:
                try:
                    insurance = float(input(f"Please enter a valid percentage value between zero and one hundred for the monthly insurance you must pay on {property.name}: "))    
                except:
                    try:
                        insurance = float(input(f"Sorry, Brandon, I did not understand. Please enter the monthly insurance on {property.name}, as a percentage value between zero and one hundred: "))    
                    except:
                        print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += (insurance/100)*property.cost
        anyutilities = input(f'Do you pay for any of the utilities on {property.name}? ')
        if anyutilities.lower() not in {'yes','no'}:
            anyutilities = input('I did not understand you, Brandon. Please answer yes or no. ')
        while anyutilities.lower() not in {'yes','no'}:
            anyutilities = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if anyutilities.lower() == 'yes':
            utilities = {'electricity','water','sewage','garbage','gas'}
            for u in utilities:
                anyquery = input(f'Do you pay for any {u} at {property.name}? ')
                if anyquery.lower() not in {'yes','no'}:
                    anyquery = input('I did not understand you, Brandon. Please answer yes or no. ')
                while anyquery.lower() not in {'yes','no'}:
                    anyquery = input('We could go on like this all day, Brandon. Please answer yes or no. ')
                if anyquery.lower() == 'yes':
                    try:
                        util = float(input(f"Ok, Brandon. Enter your monthly {u} bill on {property.name}: "))
                    except:
                        try:
                            util = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for your monthly electricity bill on {property.name}: "))
                        except:
                            print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
                    property.expenses += util
        else:
            print('You truly are an entrepreneurial savant, Brandon.')
        anyhoa = input(f'Do you pay any HOA fees for {property.name}? ')
        if anyhoa.lower() not in {'yes','no'}:
            anyhoa = input('I did not understand you, Brandon. Please answer yes or no. ')
        while anyhoa.lower() not in {'yes','no'}:
            anyhoa = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if anyhoa.lower() == 'yes':
            try:
                hoa = float(input(f"Ok, Brandon, enter your monthly HOA fees for {property.name}. "))
            except:
                try:
                    hoa = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for your monthly HOA fees for {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += hoa
        else:
            print('Bravo, Brandon! Those things are a real nuisance.')
        anylawn = input(f'Do you pay for any lawn maintenance or snow removal for {property.name}? ')
        if anylawn.lower() not in {'yes','no'}:
            anylawn = input('I did not understand you, Brandon. Please answer yes or no. ')
        while anylawn.lower() not in {'yes','no'}:
            anylawn = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if anylawn.lower() == 'yes':
            try:
                lawnsnow = float(input(f"Ok, Brandon, enter your monthly lawn and/or snow fees for {property.name}. "))
            except:
                try:
                    lawnsnow = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for your monthly lawn and/or snow fees for {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += lawnsnow
        else:
            print('That is most wise, Brandon--let the tenants pay for it themselves if they want it so much.')
        exactvacancy = input(f'Do you know the exact monthly vacancy allowance to be set aside for {property.name}? (If not, we shall estimate it at five percent of rental income).) ')
        if exactvacancy.lower() not in {'yes','no'}:
            exactvacancy = input('I did not understand you, Brandon. Please answer yes or no. ')
        while exactvacancy.lower() not in {'yes','no'}:
            exactvacancy = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if exactvacancy.lower() == 'yes':
            try:
                vacancy = float(input(f"You are truly extraordinary, Brandon. Please enter the exact monthly vacancy allowance for {property.name}: "))
            except:
                try:
                    vacancy = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the exact monthly vacancy allowance for {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += vacancy
        else:
            pass
        exactrepairs = input(f'Do you know the exact monthly repairs allowance to be set aside for {property.name}? (If not, we shall estimate it at $100 per unit).) ')
        if exactrepairs.lower() not in {'yes','no'}:
            exactrepairs = input('I did not understand you, Brandon. Please answer yes or no. ')
        while exactrepairs.lower() not in {'yes','no'}:
            exactrepairs = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if exactrepairs.lower() == 'yes':
            try:
                repairs = float(input(f"You are unassailably scrupulous in your accounting, Brandon. Please enter the exact monthly repairs allowance for {property.name}: "))
            except:
                try:
                    repairs = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the exact monthly repairs allowance for {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += repairs
        else:
            property.expenses += 100*len(property.units)
        exactcapex = input(f'Do you know the exact capital expenditures allowance to be set aside for {property.name}? (If not, we shall estimate it at $100.) ')
        if exactcapex.lower() not in {'yes','no'}:
            exactcapex = input('I did not understand you, Brandon. Please answer yes or no. ')
        while exactcapex.lower() not in {'yes','no'}:
            exactcapex = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if exactcapex.lower() == 'yes':
            try:
                capex = float(input(f"Marvelous, Brandon, your foresight knows no bounds. Please enter the exact capital expenditure allowance for {property.name}: "))
            except:
                try:
                    capex = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the exact capital expenditure allowance for {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += capex
        else:
            property.expenses += 100
        anymanager = input(f'Do you pay someone else to manage {property.name}? ')
        if anymanager.lower() not in {'yes','no'}:
            anymanager = input('I did not understand you, Brandon. Please answer yes or no. ')
        while anymanager.lower() not in {'yes','no'}:
            anymanager = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if anymanager.lower() == 'yes':
            try:
                manager = float(input(f"Good thinking, Brandon, a busy man such as yourself does well to exploit the division of labor in society. How much do you pay monthly for property management at {property.name}? "))
            except:
                try:
                    manager = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for your monthly payment for property management at {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += manager
        else:
            print("Of course you don't, Brandon. Why would a self-reliant, pecunious and proactive fellow like yourself hire someone else to handle your lucrative business? Pardon me for asking.")
        knowmortgage = input(f'Do you know the percentage for your monthly mortgage payment on {property.name}? (If not, we shall assume a standard rate of five percent.) ')
        if knowmortgage.lower() not in {'yes','no'}:
            knowmortgage = input('I did not understand you, Brandon. Please answer yes or no. ')
        while knowmortgage.lower() not in {'yes','no'}:
            knowmorgage = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if knowmortgage.lower() == 'yes':
            try:
                mortgage = float(input(f"Why did I even ask? You know all things, Brandon. Please enter the exact monthly mortgage payment on {property.name}: "))
            except:
                try:
                    mortgage = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the exact monthly mortgage payment on {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.expenses += mortgage             
        else:
            property.expenses += .05 * (property.cost - property.downpayment)
        print(f'\nOk Brandon, that brings your monthly expenses on {property.name} to ${property.expenses:,.2f}. Now it is time for me to proceed to the third box in your infallible Four Square method, to calculate your monthly cash flow.')
        pocketbulge = input('Can you feel your pockets bulging yet? ')
        if pocketbulge.lower() not in {'yes','no'}:
            pocketbulge = input('I did not understand you, Brandon. Can you feel your pockets bulging yet? Please answer yes or no. ')
        while pocketbulge.lower() not in {'yes','no'}:
            pocketbulge = input('We could go on like this all day, Brandon. Can you feel your pockets bulging yet? Please answer yes or no. ')
        if pocketbulge.lower() == 'yes':
            print('Good, so can I.')
        else:
            print('What a pity. I hope you will soon.')
        cashflow = sum(property.units)+property.other_income-property.expenses
        print('\n\n')
        print('*'*50)
        print(f'Dearest Brandon, your monthly cash flow from {property.name} equals your monthly income of ${sum(property.units)+property.other_income:,.2f} minus your monthly expenses of ${property.expenses:,.2f}, coming to...\n\t\t${cashflow:,.2f}')
        print('Your pockets must be positively throbbing, Brandon!' if cashflow > 0 else 'I fear I may have overestimated your financial aptitude, Brandon. I am beginning to doubt the solvency of your investment.')
        print('*'*50)
        print('\n\n')
        print(f'Now for the GRAND FINALE--the glorious fourth box of your Four Square method. To calculate your cash-on-cash ROI, I just need a little more information from you to compute your total investment in {property.name}, Brandon, my liege.')
        exactclosing = input(f'\nDo you know the exact closing costs on {property.name}? (If not, we shall estimate it at fifteen percent of the total cost.) ')
        if exactclosing.lower() not in {'yes','no'}:
            exactclosing = input('I did not understand you, Brandon. Please answer yes or no. ')
        while exactclosing.lower() not in {'yes','no'}:
            exactclosing = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if exactclosing.lower() == 'yes':
            try:
                closing = float(input(f"Brandon, you are wonderfully meticulous. Please enter the exact closing costs on {property.name}: "))
            except:
                try:
                    closing = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the exact closing costs on {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
        else:
            closing = property.cost * .15
        property.totali += closing
        exactrehab = input(f'Do you know the exact rehabilitation costs on {property.name}? (If not, we shall estimate it at 35 percent of the total cost.) ')
        if exactrehab.lower() not in {'yes','no'}:
            exactrehab = input('I did not understand you, Brandon. Please answer yes or no. ')
        while exactrehab.lower() not in {'yes','no'}:
            exactrehab = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if exactrehab.lower() == 'yes':
            try:
                rehab = float(input(f"Brandon, you are wonderfully meticulous. Please enter the exact rehabilitation costs on {property.name}: "))
            except:
                try:
                    rehab = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the exact rehabilitation costs on {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
        else:
            rehab = property.cost * .35
        property.totali += rehab
        anymisc = input(f'Are there any other miscellaneous costs (bribes, intimidation, etc.) to count towards your total investment in {property.name}? ')
        if anymisc.lower() not in {'yes','no'}:
            anymisc = input('I did not understand you, Brandon. Please answer yes or no. ')
        while anymisc.lower() not in {'yes','no'}:
            anymisc = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if anymisc.lower() == 'yes':
            try:
                misccost = float(input(f"Brandon, I will not ask you to incriminate yourself, but please enter the total miscellaneous costs to count towards your total investment in {property.name}: "))
            except:
                try:
                    misccost = float(input(f"Sorry, Brandon, I did not understand. Please enter a valid number for the miscellaneous costs on {property.name}: "))
                except:
                    print('I am sorry you feel like being difficult, Brandon, please come back when you are ready to enter a valid number. Have a nice day.')
            property.totali += misccost
        else:
            print('Your frugality is truly breathtaking, Brandon.')
        ready = input('\nAre you ready for the GRAND FINALE? ')
        if ready.lower() not in {'yes','no'}:
            ready = input('I said, ARE YOU READY FOR THE GRAND FINALE? ')
        while ready.lower() not in {'yes','no'}:
            ready = input('We could go on like this all day, Brandon. Please answer yes or no. ')
        if ready.lower() == 'yes':
            property.totali += property.downpayment
            print(f"\nBrandon, Your Excellency, your total investment in {property.name} is ${property.totali:,.2f}.")
            print(f"\n\nThat means your Cash-on-Cash annual ROI is...\n\n\n\t\t\t%{(cashflow*1200)/property.totali:,.2f}!")
            print('*'*50)
        else:
            print('Ok, Brandon, see you next time. Goodbye!')

# %%
ROIbot = BrandonInterface()
ROIbot.serve_Brandon()
# Out:
# Greetings, Brandon, I exist solely in order to make your pockets even bigger than they already are. What is the name of the property whose ROI you wish me to analyze? legoland
# What is the total cost of Legoland? 99998
# And what is your down payment on Legoland? 887
# Ok, Brandon, let's use your famous Four Square method and start by calculating your monthly income from Legoland. How many rental units are in Legoland? 11
# Is the rent for each unit in Legoland the same? no
# Ok, Brandon, no problem. Do any of the units in Legoland have the same rent? yes
# Ok, Brandon, no problem. How many groups of units in Legoland have the same rent? 2
# Ok, Brandon, how many units are in group 1? 3
# And what is the rent for each unit in group 1? 120
# Ok, Brandon, how many units are in group 2? 4
# And what is the rent for each unit in group 2? 99
# Ok, Brandon, that means 7 out of 11 units belong to groups with the same rent. That leaves 4 with different rent.
#
# ...
